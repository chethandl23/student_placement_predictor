# %%
import pandas as pd 
import numpy as np
from category_encoders import BinaryEncoder
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
data = pd.read_csv(r"C:\code crafters\data\Copy of code crafters.csv")
data.head()
# Out:
#                            Email               Name  Gender   10th board  \
# 0          payal_roy79@gmail.com          Payal Roy  Female  State Board
# 1      shreyoshi_dey13@gmail.com      Shreyoshi Dey  Female        WBBSE
# 2        rohan_nandi12@gmail.com        Rohan Nandi    Male  State Board
# 3      smita_agarwal90@gmail.com      Smita Agarwal  Female         CBSE
# 4  samaira_singhania95@gmail.com  Samaira Singhania  Female         ICSE
#
#    10th marks         12th board  12th marks  \
# 0        96.7               CBSE        70.2
# 1        96.2             WBCHSE        90.6
# 2        97.5               CBSE        69.6
# 3        96.9  Other state Board        77.6
# 4        99.1               CBSE        62.8
#
#                                          Stream  Cgpa Internships(Y/N)  \
# 0      Artificial Intelligence and Data Science  7.37               No
# 1  Artificial Intelligence and Machine Learning  9.35               No
# ...

# %%
# ignore unwanted columns like email,name etc
data = data.drop(columns=['Email', 'Name', '10th board', '12th board'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   789 non-null    object
#  1   10th marks               789 non-null    float64
#  2   12th marks               789 non-null    float64
#  3   Stream                   789 non-null    object
#  4   Cgpa                     789 non-null    float64
#  5   Internships(Y/N)         789 non-null    object
#  6   Training(Y/N)            789 non-null    object
#  7   Backlog in 5th sem       789 non-null    float64
#  8   Innovative Project(Y/N)  789 non-null    object
#  9   Communication level      789 non-null    float64
#  10  Technical Course         789 non-null    float64
#  11  Placement(Y/N)?          789 non-null    object
#  12  Required job role        789 non-null    object
#  13  Unnamed: 17              0 non-null      float64
# ...

# %%
data.columns.tolist()
# Out:
# ['Gender',
#  '10th marks',
#  '12th marks',
#  'Stream',
#  'Cgpa',
#  'Internships(Y/N)',
#  'Training(Y/N)',
#  'Backlog in 5th sem',
#  'Innovative Project(Y/N)',
#  'Communication level',
#  'Technical Course',
#  'Placement(Y/N)?',
#  'Required job role ',
#  'Unnamed: 17']

# %%
data['Unnamed: 17'].head()
data['Unnamed: 17'].isna().all()  # should be True based on info()
# Out:
# np.True_

# %%
data = data.drop(columns=['Unnamed: 17'])

# %%
data.head()
# Out:
#    Gender  10th marks  12th marks  \
# 0  Female        96.7        70.2
# 1  Female        96.2        90.6
# 2    Male        97.5        69.6
# 3  Female        96.9        77.6
# 4  Female        99.1        62.8
#
#                                          Stream  Cgpa Internships(Y/N)  \
# 0      Artificial Intelligence and Data Science  7.37               No
# 1  Artificial Intelligence and Machine Learning  9.35               No
# 2                        Information Technology  7.84               No
# 3      Artificial Intelligence and Data Science  7.87              Yes
# 4                        Information Technology  9.26              Yes
#
#   Training(Y/N)  Backlog in 5th sem Innovative Project(Y/N)  \
# 0           Yes                 2.0                      No
# 1            No                 0.0                     Yes
# 2           Yes                 0.0                     Yes
# 3            No                 0.0                     Yes
# ...

# %%
new_column_names = {
    'Internships(Y/N)': 'Internships',
    'Training(Y/N)': 'Training',
    'Innovative Project(Y/N)': 'Innovative Project',
    'Backlog in 5th sem': 'Backlogs',
    'Placement(Y/N)?': 'Placement',
    'Required job role ': 'Required job role' # Removing the trailing space
}

data.rename(columns=new_column_names, inplace=True)

# %%
data.head()
# Out:
#    Gender  10th marks  12th marks  \
# 0  Female        96.7        70.2
# 1  Female        96.2        90.6
# 2    Male        97.5        69.6
# 3  Female        96.9        77.6
# 4  Female        99.1        62.8
#
#                                          Stream  Cgpa Internships Training  \
# 0      Artificial Intelligence and Data Science  7.37          No      Yes
# 1  Artificial Intelligence and Machine Learning  9.35          No       No
# 2                        Information Technology  7.84          No      Yes
# 3      Artificial Intelligence and Data Science  7.87         Yes       No
# 4                        Information Technology  9.26         Yes      Yes
#
#    Backlogs Innovative Project  Communication level  Technical Course  \
# 0       2.0                 No                  3.0               2.0
# 1       0.0                Yes                  4.0               2.0
# 2       0.0                Yes                  3.0               4.0
# ...
